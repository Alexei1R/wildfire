# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import pandas as pd
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, LSTM, concatenate, Lambda
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
import numpy as np
import os
import tensorflow as tf

# %% [markdown]
# # Define Data Processors

# %%
from PIL import Image

# Disable the decompression bomb error warning by increasing the pixel limit
Image.MAX_IMAGE_PIXELS = None

# %%
def split_and_reshufle_data(df, test_size_ratio=0.8) ->  'pd.DataFrame':
    train_set, test_set = train_test_split(df, test_size=test_size_ratio)
    train_set = train_set.reset_index(drop=True)
    test_set = test_set.reset_index(drop=True)
    return train_set, test_set

# %%
def split_image(df):
    """
    Splits the 'filename' column from the rest of the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame containing the data.

    Returns:
        tuple: A tuple containing:
            - path_to_images (pd.Series): The 'filename' column.
            - remaining_df (pd.DataFrame): The DataFrame without the 'path_to_image' column.
    """
    # Separate the 'path_to_image' column
    filename_images = df['filename'].values
    # Drop the 'path_to_image' column from the DataFrame
    remaining_df = df.drop(columns=['filename'])
    return filename_images, remaining_df

# %%
def split_target(df, target_column):
    """
    Splits the target column from the rest of the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame containing the data.
        target_column (str): The name of the target column.

    Returns:
        tuple: A tuple containing:
            - target (pd.Series): The target column.
            - features_df (pd.DataFrame): The DataFrame without the target column.
    """
    # Separate the target column
    target = df[target_column]
    # Drop the target column from the DataFrame
    features_df = df.drop(columns=[target_column])
    return features_df, target

# %%
def process_tabular_data(df, drop_columns=['date', 'lat', 'long', 'absolute_time']):
    """
    Processes tabular data by dropping specified columns.

    Parameters:
        df (pd.DataFrame): The original DataFrame.
        drop_columns (list): List of column names to be dropped.

    Returns:
        pd.DataFrame: The processed DataFrame (without the dropped columns).
    """
    # Drop the specified columns
    df_processed = df.drop(columns=drop_columns)

    # Return the processed DataFrame
    return df_processed

# %%
def process_images(image_paths, target_size=(300, 430)):
    """
    Processes image paths into numpy arrays suitable for model input.

    Parameters:
        image_paths (list): List of paths to the image files.
        target_size (tuple): Target size for resizing images (default: (300, 430)).

    Returns:
        numpy.ndarray: Array of processed images with shape (n_samples, target_size[0], target_size[1], 3).
    """
    processed_images = []
    for path in image_paths:
        # Load the image
        img = load_img(path, target_size=target_size)
        # Convert the image to a numpy array
        img_array = img_to_array(img)
        # Normalize the image array to [0, 1]
        img_array = img_array / 255.0
        processed_images.append(img_array)

    return np.array(processed_images)

# %% [markdown]
# # Processing Data

# %%
path_to_original_csv = '/content/drive/MyDrive/Projects/Cassini/data/combined_dataset.csv'

# %%
original_df = pd.read_csv(path_to_original_csv)

# %%
original_df
# Out:
#                                filename        date      lat     long  \
# 0      41.06599_26.07051_02-01-2023.jpg  02-01-2023  41.0660  26.0705
# 1      41.11273_26.14135_02-01-2023.jpg  02-01-2023  41.1127  26.1414
# 2      41.14205_26.17694_02-01-2023.jpg  02-01-2023  41.1421  26.1769
# 3      41.16845_26.17591_02-01-2023.jpg  02-01-2023  41.1685  26.1759
# 4      41.19282_26.23720_02-01-2023.jpg  02-01-2023  41.1928  26.2372
# ..                                  ...         ...      ...      ...
# 103    37.96168_23.06582_14-07-2023.jpg  14-07-2023  37.9617  23.0658
# 104    36.07271_27.93581_18-07-2023.jpg  18-07-2023  36.0727  27.9358
# 105    36.09572_27.93561_18-07-2023.jpg  18-07-2023  36.0957  27.9356
# 106     41.23504_25.9001_01-11-2022.jpg  01-11-2022  41.2350  25.9001
# 107  37.939132_23.037807_14-07-2023.jpg  14-07-2023  37.9391  23.0378
#
#      absolute_time  pressure  humidity   temp  wind_speed  wind_deg  clouds  \
# 0       1672664400      1030        61  11.69        0.16       179       0
# 1       1672664400      1030        67  11.91        0.34       115       0
# 2       1672664400      1030        63  12.63        0.52       162       0
# 3       1672664400      1030        63  11.80        0.52       162       0
# 4       1672664400      1030        63  12.86        0.52       162       0
# ..             ...       ...       ...    ...         ...       ...     ...
# 103     1689339600      1012        45  38.51        1.39       293       3
# 104     1689685200      1005        55  28.86        2.75       278       0
# 105     1689685200      1005        55  28.99        2.75       278       0
# 106     1667307600      1022        52  22.01        2.27        48      53
# 107     1689339600      1012        45  39.82        1.39       293       3
#
#      potential_wildfire
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 103                   1
# 104                   1
# 105                   1
# 106                   1
# 107                   1
#
# [108 rows x 12 columns]

# %%
test_set, train_set = split_and_reshufle_data(original_df)

train_path_image, train_df = split_image(train_set)
test_path_image, test_df = split_image(test_set)

X_train_tabular, y_train = split_target(train_df, target_column="potential_wildfire")
X_test_tabular, y_test = split_target(test_df, target_column="potential_wildfire")


X_train_tabular = process_tabular_data(X_train_tabular)
X_test_tabular = process_tabular_data(X_test_tabular)

# %%
X_train_tabular.columns
# Out:
# Index(['pressure', 'humidity', 'temp', 'wind_speed', 'wind_deg', 'clouds'], dtype='object')

# %%
path_to_all_images = '/content/drive/MyDrive/Projects/Cassini/data/COMMON'
train_path_image = [os.path.join(path_to_all_images, i) for i in train_path_image]
test_path_image = [os.path.join(path_to_all_images, i) for i in test_path_image]

# %%
X_train_images_array = process_images(train_path_image)
X_test_images_array = process_images(test_path_image)

# %%
X_train_tabular
# Out:
#     pressure  humidity   temp  wind_speed  wind_deg  clouds
# 0       1011        30  34.67        8.23        30      20
# 1       1030        63  11.80        0.52       162       0
# 2       1013        47  24.18        3.55        28      36
# 3       1005        55  28.20        2.75       278       0
# 4       1005        55  28.86        2.75       278       0
# ..       ...       ...    ...         ...       ...     ...
# 82      1005        69  12.69        1.18       257      18
# 83      1001        14  38.56        9.52       138      70
# 84      1013        47  23.60        3.55        28      36
# 85      1013        47  23.39        3.55        28      36
# 86      1022        48  20.13        0.83       185       0
#
# [87 rows x 6 columns]

# %% [markdown]
# # Define Model Architecture

# %%
def build_model():
    """
    Builds a dual-input neural network model with an image branch and a tabular branch.

    Returns:
        keras.Model: The compiled model.
    """
    # Image processing branch
    image_input = Input(shape=(300, 430, 3))
    base_model = ResNet50(include_top=False, input_shape=(300, 430, 3), weights='imagenet')
    x = base_model(image_input)
    x = Flatten()(x)
    image_branch_output = Dense(128, activation=tf.keras.layers.LeakyReLU(negative_slope=0.3))(x)

    # Tabular data processing branch
    tabular_input = Input(shape=(6,))
    # Wrap tf.expand_dims in a Lambda layer
    tabular_input_expanded = Lambda(lambda x: tf.expand_dims(x, axis=1))(tabular_input)
    tabular_branch_output = Dense(128, activation='sigmoid')(tabular_input_expanded)

    # Combine the outputs of the two branches
    combined = concatenate([image_branch_output, tabular_branch_output])
    z = Dense(128, activation='sigmoid')(combined)

    # Output layer with one unit for binary classification
    output = Dense(1, activation='sigmoid')(z)

    # Build and compile the model
    model = Model(inputs=[image_input, tabular_input], outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Training model

# %%
model_save_path = "/content/drive/MyDrive/Projects/Cassini/models/model2.h5"

# %%
# Initialize the model
model = build_model()

# Train the model
model.fit(
    [X_train_images_array, X_train_tabular],  # Input: Images and Tabular data
    y_train,
    validation_data=([X_test_images_array, X_test_tabular], y_test),
    epochs=50,
    batch_size=10,
    verbose=1
)

# Save the model to the specified path
model.save(model_save_path)
print(f"Model saved at {model_save_path}")
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 108s 5s/step - accuracy: 0.6827 - loss: 0.6471 - val_accuracy: 0.4286 - val_loss: 1.2510
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.8421 - loss: 0.4390 - val_accuracy: 0.4286 - val_loss: 1.3956
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - accuracy: 0.8738 - loss: 0.2845 - val_accuracy: 0.5714 - val_loss: 0.6831
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 278ms/step - accuracy: 0.9642 - loss: 0.1787 - val_accuracy: 0.4286 - val_loss: 1.2887
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - accuracy: 0.9515 - loss: 0.1472 - val_accuracy: 0.4286 - val_loss: 1.9030
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.8333 - loss: 0.4231 - val_accuracy: 0.4286 - val_loss: 2.4962
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.7881 - loss: 0.4753 - val_accuracy: 0.4286 - val_loss: 2.3794
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - accuracy: 0.8990 - loss: 0.2344 - val_accuracy: 0.5714 - val_loss: 0.6836
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.8960 - loss: 0.1997 - val_accuracy: 0.5714 - val_loss: 0.6829
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.9771 - loss: 0.1200 - val_accuracy: 0.4286 - val_loss: 2.3568
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.8348 - loss: 0.3290 - val_accuracy: 0.4286 - val_loss: 2.4463
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.9161 - loss: 0.2269 - val_accuracy: 0.4286 - val_loss: 1.0269
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - accuracy: 0.9037 - loss: 0.2473 - val_accuracy: 0.5714 - val_loss: 0.8846
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.8750 - loss: 0.3123 - val_accuracy: 0.5714 - val_loss: 1.0906
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.9007 - loss: 0.2297 - val_accuracy: 0.5714 - val_loss: 1.1443
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - accuracy: 0.9572 - loss: 0.0957 - val_accuracy: 0.5714 - val_loss: 1.1470
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.9573 - loss: 0.0919 - val_accuracy: 0.5714 - val_loss: 1.2525
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.9855 - loss: 0.0650 - val_accuracy: 0.5714 - val_loss: 1.6639
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.9906 - loss: 0.0475 - val_accuracy: 0.5714 - val_loss: 1.1606
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.4286 - val_loss: 0.8097
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - accuracy: 0.9950 - loss: 0.0326 - val_accuracy: 0.6190 - val_loss: 0.7007
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.6190 - val_loss: 0.6767
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 292ms/step - accuracy: 0.9954 - loss: 0.0157 - val_accuracy: 0.6190 - val_loss: 0.6762
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.9889 - loss: 0.0626 - val_accuracy: 0.7619 - val_loss: 0.5452
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.9929 - loss: 0.0172 - val_accuracy: 0.6190 - val_loss: 0.6774
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.9950 - loss: 0.0293 - val_accuracy: 0.6190 - val_loss: 0.6741
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.9705 - loss: 0.1405 - val_accuracy: 0.5714 - val_loss: 0.6761
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.9864 - loss: 0.0489 - val_accuracy: 0.6190 - val_loss: 0.6336
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.9867 - loss: 0.0590 - val_accuracy: 0.6190 - val_loss: 0.6037
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.8772 - loss: 0.2995 - val_accuracy: 0.5714 - val_loss: 1.7801
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.9027 - loss: 0.2359 - val_accuracy: 0.5714 - val_loss: 0.7147
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - accuracy: 0.8427 - loss: 0.3922 - val_accuracy: 0.5714 - val_loss: 0.8119
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.9510 - loss: 0.1827 - val_accuracy: 0.4286 - val_loss: 2.1760
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - accuracy: 0.9747 - loss: 0.1114 - val_accuracy: 0.4286 - val_loss: 1.9512
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 0.9093 - loss: 0.2206 - val_accuracy: 0.6190 - val_loss: 0.6799
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - accuracy: 0.9448 - loss: 0.1202 - val_accuracy: 0.5714 - val_loss: 0.8632
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 0.5714 - val_loss: 1.0105
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.9950 - loss: 0.0531 - val_accuracy: 0.5714 - val_loss: 1.0545
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9889 - loss: 0.0592 - val_accuracy: 0.5714 - val_loss: 1.0758
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.5714 - val_loss: 1.1092
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.5714 - val_loss: 1.1342
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - accuracy: 0.9977 - loss: 0.0118 - val_accuracy: 0.5714 - val_loss: 1.1528
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.5714 - val_loss: 1.1710
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.5714 - val_loss: 1.1855
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.5714 - val_loss: 1.1928
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.5714 - val_loss: 1.1987
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - accuracy: 0.9705 - loss: 0.0291 - val_accuracy: 0.5714 - val_loss: 1.1962
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.5714 - val_loss: 1.1960
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5714 - val_loss: 1.1956
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5714 - val_loss: 1.1944
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved at /content/drive/MyDrive/Projects/Cassini/models/model2.h5

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
import numpy as np

# Evaluate the model on the test set
y_pred_probs = model.predict([X_test_images_array, X_test_tabular])  # Predict probabilities
y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_probs)

# Print the metrics
print("Evaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC-AUC Score: {roc_auc:.4f}")

# Optional: Print a classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Evaluation Metrics:
# Accuracy: 0.5714
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC-AUC Score: 0.6667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73        12
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.57        21
#    macro avg       0.29      0.50      0.36        21
# weighted avg       0.33      0.57      0.42        21
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Prediction

# %%
# Function to make a prediction for a single input
def predict_single(image_path, tabular_input, model):
    """
    Predicts output for a single image and tabular input.

    Parameters:
        image_path (str): Path to the image.
        tabular_input (list or array): Tabular input data as a 1D array.
        model (Model): The trained model.

    Returns:
        numpy.ndarray: Predicted output.
    """
    # Process the image
    image_array = process_images([image_path])  # Returns a 4D array (1, 300, 300, 3)
    # Convert tabular input to a 2D array (1, 6)
    tabular_array = np.expand_dims(tabular_input, axis=0)
    # Make prediction
    prediction = model.predict([image_array, tabular_array])
    return prediction

# %%
# Example: Predict for a single input
example_image_path = test_path_image[0]  # Use a test image path
example_tabular_input = X_test_tabular.iloc[0]  # Use corresponding tabular data
prediction = predict_single(example_image_path, example_tabular_input, model)

print("Prediction for single input:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Prediction for single input: [[0.03454247]]

# %% [markdown]
# # TESTING

# %%
path_photos = '/content/drive/MyDrive/Projects/Cassini/data/TRUE'

# %%
import os

# %%
def create_fake_dataset(image_folder_path, num_columns=6):
    """
    Creates a fake dataset from images in a folder with random tabular data and binary target.

    Parameters:
        image_folder_path (str): Path to the folder containing images.
        num_columns (int): Number of random columns to generate (default: 6).

    Returns:
        pd.DataFrame: A DataFrame with image paths, random tabular data, and a binary target column.
    """
    # Get a list of image paths
    image_paths = [
        os.path.join(image_folder_path, filename)
        for filename in os.listdir(image_folder_path)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg'))
    ]

    if not image_paths:
        raise ValueError(f"No images found in the folder: {image_folder_path}")

    # Generate random data for columns
    num_images = len(image_paths)
    random_data = {
        f"column{i+1}": np.random.rand(num_images) for i in range(num_columns)
    }

    # Generate random binary target column
    random_data['target'] = np.random.choice([0, 1], size=num_images)

    # Add image paths to the DataFrame
    random_data['path_to_image'] = image_paths

    # Create DataFrame
    df = pd.DataFrame(random_data)

    return df

# %%
fake_df  = create_fake_dataset(path_photos)

# %%
fake_df
# Out:
#      column1   column2   column3   column4   column5   column6  target  \
# 0   0.198597  0.937631  0.906592  0.577526  0.065384  0.775842       0
# 1   0.057167  0.121903  0.993898  0.072478  0.903601  0.170554       1
# 2   0.469939  0.620575  0.693336  0.017758  0.976206  0.635406       0
# 3   0.561949  0.642366  0.544218  0.825793  0.916712  0.460333       1
# 4   0.956612  0.846405  0.869270  0.676869  0.412658  0.485153       1
# 5   0.245115  0.772364  0.788404  0.286908  0.553916  0.776835       0
# 6   0.370756  0.045522  0.511941  0.282198  0.762601  0.667828       1
# 7   0.723349  0.975001  0.722528  0.301466  0.453865  0.233122       0
# 8   0.076485  0.927260  0.855316  0.327749  0.497369  0.257699       1
# 9   0.664170  0.080772  0.419019  0.564154  0.995753  0.080996       1
# 10  0.134370  0.340487  0.922852  0.023177  0.105229  0.891281       1
# 11  0.795949  0.032406  0.040318  0.703526  0.969997  0.386254       0
# 12  0.460232  0.729210  0.071356  0.458933  0.674950  0.599810       1
# 13  0.280585  0.848061  0.606210  0.925861  0.369864  0.423652       0
# 14  0.176977  0.227013  0.638214  0.920986  0.361225  0.634420       1
# 15  0.165149  0.903499  0.612968  0.101762  0.366706  0.251049       1
# 16  0.203656  0.717041  0.912195  0.856721  0.188003  0.376783       1
# 17  0.033212  0.753350  0.029675  0.936506  0.036248  0.583327       0
# 18  0.654054  0.273068  0.757629  0.799202  0.522201  0.587712       0
# 19  0.366375  0.312898  0.051150  0.540986  0.089849  0.518475       1
# 20  0.848858  0.385473  0.352083  0.418823  0.390723  0.478352       1
# 21  0.215119  0.762071  0.879443  0.131923  0.289550  0.786345       0
# 22  0.524004  0.664745  0.454809  0.816945  0.304173  0.106110       0
# 23  0.764553  0.598224  0.895481  0.040207  0.309857  0.680425       1
# 24  0.892391  0.418065  0.503350  0.795225  0.903694  0.760751       1
# 25  0.124277  0.493759  0.381586  0.923731  0.236139  0.936426       1
# 26  0.650621  0.468727  0.251845  0.044557  0.596692  0.634400       0
# 27  0.340659  0.207865  0.221866  0.214663  0.096032  0.749349       1
# 28  0.260596  0.953782  0.914688  0.341385  0.117890  0.840967       0
# 29  0.789970  0.758313  0.320368  0.126205  0.943422  0.956959       1
# 30  0.850818  0.739411  0.967694  0.680106  0.380424  0.467934       0
# 31  0.796631  0.065335  0.172439  0.676501  0.400386  0.924406       0
# 32  0.314290  0.180607  0.033614  0.119468  0.342436  0.405542       0
# 33  0.845943  0.304052  0.597068  0.432001  0.552338  0.319524       0
# 34  0.342285  0.098023  0.800978  0.519195  0.499828  0.499288       1
# 35  0.081050  0.511310  0.459388  0.196458  0.838639  0.666366       0
# 36  0.894106  0.617068  0.184193  0.636897  0.047072  0.829152       1
# 37  0.739935  0.278139  0.301745  0.280096  0.329424  0.221182       1
# 38  0.825579  0.288956  0.196196  0.403439  0.377823  0.839836       0
# 39  0.045846  0.486932  0.578125  0.339251  0.869490  0.212199       0
# 40  0.208112  0.377065  0.121965  0.354288  0.101089  0.887456       1
# 41  0.042805  0.028246  0.031950  0.152944  0.761317  0.538736       1
# 42  0.890252  0.941221  0.174482  0.786809  0.410552  0.736949       0
# 43  0.610680  0.754470  0.974562  0.134831  0.177141  0.303694       0
# 44  0.629500  0.631159  0.003787  0.134855  0.770391  0.521126       1
# 45  0.833304  0.266799  0.718154  0.731279  0.175385  0.842874       1
# 46  0.431925  0.153839  0.813173  0.124314  0.127707  0.075921       0
# 47  0.947745  0.551575  0.678134  0.568738  0.668632  0.426935       1
# 48  0.314325  0.084925  0.493822  0.239332  0.467014  0.274496       0
# 49  0.752544  0.100964  0.131361  0.883921  0.333167  0.445228       0
# 50  0.542677  0.609249  0.976879  0.946107  0.036880  0.566368       1
# 51  0.757294  0.584861  0.007079  0.122229  0.124476  0.159436       0
# 52  0.427885  0.204994  0.027427  0.847761  0.936270  0.316446       0
# 53  0.410181  0.698831  0.004277  0.243486  0.477584  0.835769       1
# 54  0.698433  0.465559  0.892547  0.262993  0.849711  0.000517       1
# 55  0.719114  0.359549  0.473662  0.070295  0.343161  0.897495       1
# 56  0.148672  0.855680  0.483309  0.134548  0.244264  0.554795       0
# 57  0.992643  0.626624  0.751311  0.430212  0.763819  0.246131       0
# 58  0.449046  0.581049  0.857434  0.282251  0.827373  0.055159       1
#
#                                         path_to_image
# 0   /content/drive/MyDrive/Projects/Cassini/data/T...
# 1   /content/drive/MyDrive/Projects/Cassini/data/T...
# 2   /content/drive/MyDrive/Projects/Cassini/data/T...
# 3   /content/drive/MyDrive/Projects/Cassini/data/T...
# 4   /content/drive/MyDrive/Projects/Cassini/data/T...
# 5   /content/drive/MyDrive/Projects/Cassini/data/T...
# 6   /content/drive/MyDrive/Projects/Cassini/data/T...
# 7   /content/drive/MyDrive/Projects/Cassini/data/T...
# 8   /content/drive/MyDrive/Projects/Cassini/data/T...
# 9   /content/drive/MyDrive/Projects/Cassini/data/T...
# 10  /content/drive/MyDrive/Projects/Cassini/data/T...
# 11  /content/drive/MyDrive/Projects/Cassini/data/T...
# 12  /content/drive/MyDrive/Projects/Cassini/data/T...
# 13  /content/drive/MyDrive/Projects/Cassini/data/T...
# 14  /content/drive/MyDrive/Projects/Cassini/data/T...
# 15  /content/drive/MyDrive/Projects/Cassini/data/T...
# 16  /content/drive/MyDrive/Projects/Cassini/data/T...
# 17  /content/drive/MyDrive/Projects/Cassini/data/T...
# 18  /content/drive/MyDrive/Projects/Cassini/data/T...
# 19  /content/drive/MyDrive/Projects/Cassini/data/T...
# 20  /content/drive/MyDrive/Projects/Cassini/data/T...
# 21  /content/drive/MyDrive/Projects/Cassini/data/T...
# 22  /content/drive/MyDrive/Projects/Cassini/data/T...
# 23  /content/drive/MyDrive/Projects/Cassini/data/T...
# 24  /content/drive/MyDrive/Projects/Cassini/data/T...
# 25  /content/drive/MyDrive/Projects/Cassini/data/T...
# 26  /content/drive/MyDrive/Projects/Cassini/data/T...
# 27  /content/drive/MyDrive/Projects/Cassini/data/T...
# 28  /content/drive/MyDrive/Projects/Cassini/data/T...
# 29  /content/drive/MyDrive/Projects/Cassini/data/T...
# 30  /content/drive/MyDrive/Projects/Cassini/data/T...
# 31  /content/drive/MyDrive/Projects/Cassini/data/T...
# 32  /content/drive/MyDrive/Projects/Cassini/data/T...
# 33  /content/drive/MyDrive/Projects/Cassini/data/T...
# 34  /content/drive/MyDrive/Projects/Cassini/data/T...
# 35  /content/drive/MyDrive/Projects/Cassini/data/T...
# 36  /content/drive/MyDrive/Projects/Cassini/data/T...
# 37  /content/drive/MyDrive/Projects/Cassini/data/T...
# 38  /content/drive/MyDrive/Projects/Cassini/data/T...
# 39  /content/drive/MyDrive/Projects/Cassini/data/T...
# 40  /content/drive/MyDrive/Projects/Cassini/data/T...
# 41  /content/drive/MyDrive/Projects/Cassini/data/T...
# 42  /content/drive/MyDrive/Projects/Cassini/data/T...
# 43  /content/drive/MyDrive/Projects/Cassini/data/T...
# 44  /content/drive/MyDrive/Projects/Cassini/data/T...
# 45  /content/drive/MyDrive/Projects/Cassini/data/T...
# 46  /content/drive/MyDrive/Projects/Cassini/data/T...
# 47  /content/drive/MyDrive/Projects/Cassini/data/T...
# 48  /content/drive/MyDrive/Projects/Cassini/data/T...
# 49  /content/drive/MyDrive/Projects/Cassini/data/T...
# 50  /content/drive/MyDrive/Projects/Cassini/data/T...
# 51  /content/drive/MyDrive/Projects/Cassini/data/T...
# 52  /content/drive/MyDrive/Projects/Cassini/data/T...
# 53  /content/drive/MyDrive/Projects/Cassini/data/T...
# 54  /content/drive/MyDrive/Projects/Cassini/data/T...
# 55  /content/drive/MyDrive/Projects/Cassini/data/T...
# 56  /content/drive/MyDrive/Projects/Cassini/data/T...
# 57  /content/drive/MyDrive/Projects/Cassini/data/T...
# 58  /content/drive/MyDrive/Projects/Cassini/data/T...

# %%
train_set, test_set = split_data(fake_df)

train_path_image, train_df = split_path_to_image(train_set)
test_path_image, test_df = split_path_to_image(test_set)

X_train_tabular, y_train = split_target(train_df, target_column="target")
X_test_tabular, y_test = split_target(test_df, target_column="target")

X_train_images_array = process_images(train_path_image)
X_test_images_array = process_images(test_path_image)

# %%
# Initialize the model
model = build_model()

# Train the model
history = model.fit(
    [X_train_images_array, X_train_tabular],  # Inputs: Images and Tabular data
    y_train,  # Target
    validation_data=([X_test_images_array, X_test_tabular], y_test),  # Validation set
    epochs=20,  # Adjust epochs as needed
    batch_size=8,  # Adjust batch size as needed
    verbose=1
)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 60s 21s/step - accuracy: 0.6742 - loss: 4.8989 - val_accuracy: 0.4375 - val_loss: 4.8357
# Epoch 2/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 18s 19s/step - accuracy: 0.7500 - loss: 0.9362
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-46c8da7bb8e6> in <cell line: 5>()
#       3
#       4 # Train the model
# ----> 5 history = model.fit(
#       6     [X_train_images_array, X_train_tabular],  # Inputs: Images and Tabular data
#       7     y_train,  # Target
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318                 for step, iterator in epoch_iterator.enumerate_epoch():
#     319                     callbacks.on_train_batch_begin(step)
# --> 320                     logs = self.train_function(iterator)
#     321                     logs = self._pythonify_logs(logs)
#     322                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
